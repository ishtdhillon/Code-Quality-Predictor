# %%
import pandas as pd

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("../dataset/raw/code_quality.csv")

df.head()
# Out:
#     LOC  CyclomaticComplexity  Methods  Classes  CBO  LCOM  DIT  RFC  NOC  \
# 0   248                     2       48        9    7    28    3  193    1
# 1   198                    38       28        2    0    11    4   64    8
# 2  1136                    27       15       15   18    35    1  199    2
# 3   338                    14       49       11    3    11    7   29    5
# 4   960                    35        8       13    2    70    5  165    9
#
#    WMC  CommentRatio  MaintainabilityIndex Quality
# 0   87          0.37                    83    Good
# 1   78          0.01                    45    Poor
# 2   90          0.21                    34    Poor
# 3   45          0.30                    79    Good
# 4   47          0.29                    46    Poor

# %%
encoder = LabelEncoder()

df["Quality"] = encoder.fit_transform(df["Quality"])

df.head()
# Out:
#     LOC  CyclomaticComplexity  Methods  Classes  CBO  LCOM  DIT  RFC  NOC  \
# 0   248                     2       48        9    7    28    3  193    1
# 1   198                    38       28        2    0    11    4   64    8
# 2  1136                    27       15       15   18    35    1  199    2
# 3   338                    14       49       11    3    11    7   29    5
# 4   960                    35        8       13    2    70    5  165    9
#
#    WMC  CommentRatio  MaintainabilityIndex  Quality
# 0   87          0.37                    83        1
# 1   78          0.01                    45        2
# 2   90          0.21                    34        2
# 3   45          0.30                    79        1
# 4   47          0.29                    46        2

# %%
mapping = dict(zip(encoder.classes_, encoder.transform(encoder.classes_)))

print(mapping)
# Out:
# {'Average': np.int64(0), 'Good': np.int64(1), 'Poor': np.int64(2)}

# %%
X = df.drop("Quality", axis=1)

y = df["Quality"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (2400, 12)
# (600, 12)

# %%
processed = pd.concat([X, y], axis=1)

processed.to_csv("../dataset/processed/processed_data.csv",
                 index=False)

# %%
print("Preprocessing Completed Successfully")
# Out:
# Preprocessing Completed Successfully

# %%
import joblib

joblib.dump(encoder, "../model/label_encoder.pkl")
# Out:
# ['../model/label_encoder.pkl']
